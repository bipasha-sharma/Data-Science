# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv("hotel_bookings.csv")

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0     2.0  ...    No Deposit
# ...

# %%
data.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 1
# children                               4
# babies                                 0
# meal                                   0
# country                              507
# market_segment                         2
# distribution_channel                   1
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     1
# assigned_room_type                     1
# booking_changes                        0
# deposit_type                          21
# ...

# %%
handle_null = data.copy()

# %%
handle_null['adults'].isna().sum()
# Out:
# 1

# %%
handle_null['adults'] =handle_null['adults'].fillna(handle_null['adults'].mean())

# %%
handle_null['adults'].isna().sum()
# Out:
# 0

# %%
handle_null['children'] =handle_null['children'].fillna(handle_null['children'].mode()[0])

# %%
handle_null['children'].isna().sum()
# Out:
# 0

# %%
handle_null['country'] =handle_null['country'].fillna(handle_null['country'].mode()[0])

# %%
handle_null['children'].isna().sum()
# Out:
# 0

# %%
handle_null['market_segment'].isna().sum()
# Out:
# 2

# %%
handle_null['market_segment'].describe()
# Out:
# count        119388
# unique            8
# top       Online TA
# freq          56477
# Name: market_segment, dtype: object

# %%
handle_null['market_segment'] =handle_null['market_segment'].fillna(handle_null['market_segment'].mode()[0])

# %%
handle_null['distribution_channel'] =handle_null['distribution_channel'].fillna(handle_null['distribution_channel'].mode()[0])

# %%
handle_null['reserved_room_type'] =handle_null['reserved_room_type'].fillna(handle_null['reserved_room_type'].mode()[0])

# %%
handle_null['assigned_room_type'] =handle_null['assigned_room_type'].fillna(handle_null['assigned_room_type'].mode()[0])

# %%
handle_null['deposit_type'] =handle_null['deposit_type'].fillna(handle_null['deposit_type'].mode()[0])

# %%
handle_null['agent'] =handle_null['agent'].fillna(handle_null['agent'].mean())

# %%
handle_null['company'] =handle_null['company'].fillna(handle_null['company'].mean())

# %%
handle_null['customer_type'] =handle_null['customer_type'].fillna(handle_null['customer_type'].mode()[0])

# %%
handle_null['reservation_status'] =handle_null['reservation_status'].fillna(handle_null['reservation_status'].mode()[0])

# %%
handle_null.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
handle_null['lead_time'].describe()
# Out:
# count    119390.000000
# mean        104.011416
# std         106.863097
# min           0.000000
# 25%          18.000000
# 50%          69.000000
# 75%         160.000000
# max         737.000000
# Name: lead_time, dtype: float64

# %%
handle_null['stays_in_weekend_nights'].describe()
# Out:
# count    119390.000000
# mean          0.927599
# std           0.998613
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max          19.000000
# Name: stays_in_weekend_nights, dtype: float64

# %%
handle_null['adults'].describe()
# Out:
# count    119390.000000
# mean          1.856402
# std           0.579261
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           2.000000
# max          55.000000
# Name: adults, dtype: float64

# %%
handle_null['children'].describe()
# Out:
# count    119390.000000
# mean          0.103886
# std           0.398555
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          10.000000
# Name: children, dtype: float64

# %%
handle_null['babies'].describe()
# Out:
# count    119390.000000
# mean          0.007949
# std           0.097436
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          10.000000
# Name: babies, dtype: float64

# %%
handle_null['previous_cancellations'].describe()
# Out:
# count    119390.000000
# mean          0.087118
# std           0.844336
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          26.000000
# Name: previous_cancellations, dtype: float64

# %%
handle_null['previous_bookings_not_canceled'].describe()
# Out:
# count    119390.000000
# mean          0.137097
# std           1.497437
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          72.000000
# Name: previous_bookings_not_canceled, dtype: float64

# %%
handle_null['days_in_waiting_list'].describe()
# Out:
# count    119390.000000
# mean          2.321149
# std          17.594721
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max         391.000000
# Name: days_in_waiting_list, dtype: float64

# %%
handle_null['adr'].describe()
# Out:
# count    119390.000000
# mean        101.831122
# std          50.535790
# min          -6.380000
# 25%          69.290000
# 50%          94.575000
# 75%         126.000000
# max        5400.000000
# Name: adr, dtype: float64

# %%
handle_null['required_car_parking_spaces'].describe()
# Out:
# count    119390.000000
# mean          0.062518
# std           0.245291
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           8.000000
# Name: required_car_parking_spaces, dtype: float64

# %%
handle_null['total_of_special_requests'].describe()
# Out:
# count    119390.000000
# mean          0.571363
# std           0.792798
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           5.000000
# Name: total_of_special_requests, dtype: float64

# %%
handle_null['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
handle_null['country'].value_counts()
# Out:
# country
# PRT    49078
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 177, dtype: int64

# %%
handle_null['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56479
# Offline TA/TO    24217
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
data['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97869
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
handle_null['is_repeated_guest'].value_counts()
# Out:
# is_repeated_guest
# 0    115580
# 1      3810
# Name: count, dtype: int64

# %%
handle_null['reserved_room_type'].value_counts()
# Out:
# reserved_room_type
# A    85995
# D    19200
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64

# %%
handle_null['assigned_room_type'].value_counts()
# Out:
# assigned_room_type
# A    74054
# D    25322
# E     7805
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64

# %%
handle_null['deposit_type'].value_counts()
# Out:
# deposit_type
# No Deposit    104652
# Non Refund     14576
# Refundable       162
# Name: count, dtype: int64

# %%
handle_null['agent'].value_counts()
# Out:
# agent
# 9.000000      31961
# 86.693382     16340
# 240.000000    13922
# 1.000000       7191
# 14.000000      3640
#               ...
# 280.000000        1
# 285.000000        1
# 289.000000        1
# 265.000000        1
# 497.000000        1
# Name: count, Length: 334, dtype: int64

# %%
handle_null['company'].value_counts()
# Out:
# company
# 189.266735    112593
# 40.000000        927
# 223.000000       784
# 67.000000        267
# 45.000000        250
#                ...
# 32.000000          1
# 11.000000          1
# 487.000000         1
# 101.000000         1
# 376.000000         1
# Name: count, Length: 353, dtype: int64

# %%
handle_null['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89617
# Transient-Party    25120
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
handle_null['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
plt.hist(data['lead_time'],
         bins=5)
plt.title("Histogram right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
grp_data = handle_null.groupby('arrival_date_month')['customer_type'].value_counts().unstack()
print(grp_data)

# Sum the total 
total_arrival_data_month = grp_data.sum(axis=1)
labels = total_arrival_data_month.index

plt.figure(figsize=(8, 8))  # Increased figure size for better visualization
plt.pie(total_arrival_data_month, labels=labels, autopct='%1.2f%%', startangle=140)
plt.title('Distribution of customer_type by arrival_data_month')
plt.show()
# Out:
# customer_type       Contract  Group  Transient  Transient-Party
# arrival_date_month
# April                    163     32       8616             2278
# August                   699     59      10493             2626
# December                 175     49       5335             1221
# February                  49     49       6376             1594
# January                   26     40       4824             1039
# July                     537     21       9829             2274
# June                     319     39       8767             1814
# March                     61     40       7723             1970
# May                      264     46       9074             2407
# November                 211     61       5233             1289
# October                  737     86       6898             3439
# September                835     55       6449             3169

# %%
plt.figure()

# %%
plt.plot(handle_null['arrival_date_day_of_month'], color= 'gray')
plt.title("Line Chat")
plt.xlabel('Index')
plt.ylabel('arrival_date_day_of_month')
plt.show()

# %%
# Bar plot for meal
plt.figure(figsize=(10, 6))
sns.countplot(x=data['meal'])
plt.title('Bar Chart of Meals')
plt.xlabel('Meals')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot of Average Daily Rate
plt.figure(figsize=(6, 12))
sns.boxplot(y=data['adr'])
plt.title('Box plot of Average Daily Rate')
plt.ylabel('Average Daily Rate')
plt.show()

# %%
# Pie chart for market segment
plt.figure(figsize=(8, 8))
segments = list(data['market_segment'].value_counts())
plt.pie(segments, 
        labels=data['market_segment'].value_counts().index,
        autopct='%.1f%%', 
        pctdistance=0.85,  # Adjust percentage label distance
       )
plt.title('Pie Chart of Market Segmentation')
plt.legend()
plt.show()

# %%
# Bar plot for Market Segments
plt.figure(figsize=(10, 6))
sns.countplot(x=data['market_segment'])
plt.title('Bar Chart of Market Segments')
plt.xlabel('Market Segments')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot of: Average Daily Rate vs. Booking Changes (not related)
plt.figure(figsize=(10, 8))
plt.scatter(x=data['adr'], y=data['booking_changes'])
plt.title('Scatter Plot of Average Daily Rate vs. Booking Changes')
plt.xlabel('Average Daily Rate')
plt.ylabel('Booking Changes')
plt.show()

# %%
# Example of a cross-tabulation heatmap
cross_tab = pd.crosstab(data['market_segment'], data['customer_type'])
plt.figure(figsize=(8, 8))
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='Blues')
plt.title('Cross-tabulation Heatmap: Market Segment vs. Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Market Segment')
plt.show()

# %%
correlation = data.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060015   0.119519           0.029639
# children                           0.005048  -0.037622           0.054624
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.0f', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()
